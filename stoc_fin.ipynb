# %%
# importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
# importing the dataset
dataset=pd.read_csv("data.csv",index_col="Date",parse_dates=True)

# %%
dataset.tail(10)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2012-01-18  14780.0  15000.0  14740.0  14980.0   650300.0
# 2012-01-17  14640.0  14820.0  14630.0  14750.0   442100.0
# 2012-01-16  14610.0  14670.0  14530.0  14610.0   360100.0
# 2012-01-13  14740.0  14780.0  14450.0  14770.0  1543700.0
# 2012-12-01  14520.0  14600.0  14330.0  14520.0   540500.0
# 2012-11-01  14360.0  14750.0  14280.0  14590.0  1043400.0
# 2012-10-01  13890.0  14390.0  13860.0  14390.0   952300.0
# 2012-06-01  13990.0  14030.0  13790.0  13850.0   765500.0
# 2012-05-01  13720.0  13840.0  13600.0  13800.0   511500.0
# 2012-04-01  14050.0  14050.0  13700.0  13720.0   559100.0

# %%
#dataset.isna().any()

# %%
dataset.head(10)
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2016-12-30  42120.0  42330.0  41700.0  41830.0  610000.0
# 2016-12-29  43000.0  43220.0  42540.0  42660.0  448400.0
# 2016-12-28  43940.0  43970.0  43270.0  43270.0  339900.0
# 2016-12-27  43140.0  43700.0  43140.0  43620.0  400100.0
# 2016-12-26  43310.0  43660.0  43090.0  43340.0  358200.0
# 2016-12-22  43660.0  43840.0  43190.0  43480.0  381600.0
# 2016-12-21  43900.0  44370.0  43610.0  44000.0  658900.0
# 2016-12-20  42910.0  43630.0  42860.0  43620.0  499400.0
# 2016-12-19  42790.0  43150.0  42740.0  43130.0  358700.0
# 2016-12-16  43350.0  43550.0  42810.0  43130.0  542000.0

# %%
dataset.info()
#to display information of dataset: their datatypes, total entries and column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1226 entries, 2016-12-30 to 2012-04-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1226 non-null   float64
#  1   High    1226 non-null   float64
#  2   Low     1226 non-null   float64
#  3   Close   1226 non-null   float64
#  4   Volume  1226 non-null   float64
# dtypes: float64(5)
# memory usage: 57.5 KB

# %%
dataset['Open'].plot(figsize=(35,10))
#give legend here
#give labels for x and y axis
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 7 day rolling mean
dataset.rolling(7).mean().head(20)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2016-12-30           NaN           NaN           NaN           NaN
# 2016-12-29           NaN           NaN           NaN           NaN
# 2016-12-28           NaN           NaN           NaN           NaN
# 2016-12-27           NaN           NaN           NaN           NaN
# 2016-12-26           NaN           NaN           NaN           NaN
# 2016-12-22           NaN           NaN           NaN           NaN
# 2016-12-21  43295.714286  43584.285714  42934.285714  43171.428571
# 2016-12-20  43408.571429  43770.000000  43100.000000  43427.142857
# 2016-12-19  43378.571429  43760.000000  43128.571429  43494.285714
# 2016-12-16  43294.285714  43700.000000  43062.857143  43474.285714
# 2016-12-15  43337.142857  43725.714286  42978.571429  43385.714286
# 2016-12-14  43335.714286  43694.285714  42907.142857  43350.000000
# 2016-12-13  43260.000000  43617.142857  42827.142857  43311.428571
# 2016-12-12  43267.142857  43564.285714  42722.857143  43187.142857
# 2016-09-12  43094.285714  43470.000000  42478.571429  43040.000000
# 2016-08-12  42907.142857  43242.857143  42205.714286  42750.000000
# 2016-07-12  42500.000000  42900.000000  41864.285714  42427.142857
# 2016-06-12  42058.571429  42417.142857  41480.000000  42020.000000
# 2016-05-12  41595.714286  41975.714286  41065.714286  41544.285714
# 2016-02-12  41191.428571  41598.571429  40684.285714  41180.000000
#
#                    Volume
# Date
# 2016-12-30            NaN
# 2016-12-29            NaN
# 2016-12-28            NaN
# 2016-12-27            NaN
# 2016-12-26            NaN
# 2016-12-22            NaN
# 2016-12-21  456728.571429
# 2016-12-20  440928.571429
# 2016-12-19  428114.285714
# 2016-12-16  456985.714286
# 2016-12-15  489457.142857
# 2016-12-14  516685.714286
# 2016-12-13  524242.857143
# 2016-12-12  540871.428571
# 2016-09-12  751757.142857
# 2016-08-12  791928.571429
# 2016-07-12  791185.714286
# 2016-06-12  789857.142857
# 2016-05-12  800100.000000
# 2016-02-12  819885.714286

# %%
dataset['Open'].plot(figsize=(35,10))
dataset.rolling(window=35).mean()['Close'].plot()
dataset.rolling(window=35).mean()['High'].plot()
dataset.rolling(window=35).mean()['Low'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#dataset['Close : 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()
#dataset[['Close','Close: 30 Day Mean']].plot(figsize=(35,10))

# %%
# Optional Specify a minimum number of periods
dataset['High'].expanding(min_periods=1).mean().plot(figsize=(30,5)) #change it to low,close,open
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)

# %%
#Data cleaning
dataset.isna().any()
# Out:
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Crearting a datastructure with 60 timesteps and 1 output
X_train=[]
y_train=[]
for i in range(60,1225):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train),np.array(y_train)
# Reshaping
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %%
# PART 2 -Building the RNN
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Initialising the RNN
regressor=Sequential()

# %%
# Adding the first LSTM layer and some dropout regularisation
regressor.add(LSTM(units= 50, return_sequences=True,input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units=50 , return_sequences=True))
regressor.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units=50 , return_sequences =True))
regressor.add(Dropout(0.2))
# Adding fourth LSTM layer and some dropout reagularisation
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam',loss='mean_squared_error')
#Fitting the RNN to the training set
regressor.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 17s 89ms/step - loss: 0.0237
# Epoch 2/100
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0064
# Epoch 3/100
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0060
# Epoch 4/100
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0061
# Epoch 5/100
# 37/37 [==============================] - 3s 91ms/step - loss: 0.0060
# Epoch 6/100
# 37/37 [==============================] - 4s 100ms/step - loss: 0.0052
# Epoch 7/100
# 37/37 [==============================] - 4s 100ms/step - loss: 0.0050
# Epoch 8/100
# 37/37 [==============================] - 4s 100ms/step - loss: 0.0045
# Epoch 9/100
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0045
# Epoch 10/100
# 37/37 [==============================] - 3s 92ms/step - loss: 0.0039
# Epoch 11/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0050
# Epoch 12/100
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0042
# Epoch 13/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0036
# Epoch 14/100
# 37/37 [==============================] - 3s 83ms/step - loss: 0.0041
# Epoch 15/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0038
# Epoch 16/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0034
# Epoch 17/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0033
# Epoch 18/100
# 37/37 [==============================] - 3s 83ms/step - loss: 0.0029
# Epoch 19/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0030
# Epoch 20/100
# 37/37 [==============================] - 4s 104ms/step - loss: 0.0033
# Epoch 21/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0029
# Epoch 22/100
# 37/37 [==============================] - 4s 108ms/step - loss: 0.0030
# Epoch 23/100
# 37/37 [==============================] - 4s 108ms/step - loss: 0.0028
# Epoch 24/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0028
# Epoch 25/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 26/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0027
# Epoch 27/100
# 37/37 [==============================] - 3s 92ms/step - loss: 0.0030
# Epoch 28/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0023
# Epoch 29/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0029
# Epoch 30/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0027
# Epoch 31/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0023
# Epoch 32/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0024
# Epoch 33/100
# 37/37 [==============================] - 4s 107ms/step - loss: 0.0026
# Epoch 34/100
# 37/37 [==============================] - 4s 94ms/step - loss: 0.0023
# Epoch 35/100
# 37/37 [==============================] - 4s 107ms/step - loss: 0.0024
# Epoch 36/100
# 37/37 [==============================] - 3s 94ms/step - loss: 0.0022
# Epoch 37/100
# 37/37 [==============================] - 4s 95ms/step - loss: 0.0025
# Epoch 38/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0021
# Epoch 39/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0022
# Epoch 40/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0022
# Epoch 41/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0023
# Epoch 42/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0020
# Epoch 43/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0020
# Epoch 44/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0020
# Epoch 45/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0021
# Epoch 46/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0020
# Epoch 47/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0020
# Epoch 48/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0018
# Epoch 49/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0020
# Epoch 50/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0017
# Epoch 51/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0018
# Epoch 52/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0018
# Epoch 53/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0018
# Epoch 54/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0016
# Epoch 55/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0019
# Epoch 56/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0017
# Epoch 57/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0017
# Epoch 58/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0017
# Epoch 59/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0016
# Epoch 60/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0016
# Epoch 61/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0015
# Epoch 62/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0018
# Epoch 63/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0015
# Epoch 64/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0018
# Epoch 65/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0015
# Epoch 66/100
# 37/37 [==============================] - 3s 84ms/step - loss: 0.0016
# Epoch 67/100
# 37/37 [==============================] - 4s 97ms/step - loss: 0.0014
# Epoch 68/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0015
# Epoch 69/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0014
# Epoch 70/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0016
# Epoch 71/100
# 37/37 [==============================] - 4s 108ms/step - loss: 0.0015
# Epoch 72/100
# 37/37 [==============================] - 4s 95ms/step - loss: 0.0014
# Epoch 73/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0014
# Epoch 74/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0014
# Epoch 75/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0013
# Epoch 76/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0013
# Epoch 77/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0014
# Epoch 78/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0014
# Epoch 79/100
# 37/37 [==============================] - 3s 92ms/step - loss: 0.0012
# Epoch 80/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0013
# Epoch 81/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0014
# Epoch 82/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0012
# Epoch 83/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0013
# Epoch 84/100
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0013
# Epoch 85/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0013
# Epoch 86/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0013
# Epoch 87/100
# 37/37 [==============================] - 3s 87ms/step - loss: 0.0012
# Epoch 88/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0011
# Epoch 89/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0011
# Epoch 90/100
# 37/37 [==============================] - 3s 88ms/step - loss: 0.0013
# Epoch 91/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0012
# Epoch 92/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0011
# Epoch 93/100
# 37/37 [==============================] - 3s 86ms/step - loss: 0.0011
# Epoch 94/100
# 37/37 [==============================] - 4s 96ms/step - loss: 0.0012
# Epoch 95/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0012
# Epoch 96/100
# 37/37 [==============================] - 3s 91ms/step - loss: 0.0012
# Epoch 97/100
# 37/37 [==============================] - 3s 89ms/step - loss: 0.0010
# Epoch 98/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0012
# Epoch 99/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0012
# Epoch 100/100
# 37/37 [==============================] - 3s 85ms/step - loss: 0.0010

# %%
# Part 3 - Making the predictions and visualising the results
#Getting the real stock price of 2017
dataset_test=pd.read_csv('data.csv',index_col="Date",parse_dates=True)

# %%
real_stock_price=dataset_test.iloc[:,1:2].values

# %%
dataset_test.head()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2016-12-30  42120.0  42330.0  41700.0  41830.0  610000.0
# 2016-12-29  43000.0  43220.0  42540.0  42660.0  448400.0
# 2016-12-28  43940.0  43970.0  43270.0  43270.0  339900.0
# 2016-12-27  43140.0  43700.0  43140.0  43620.0  400100.0
# 2016-12-26  43310.0  43660.0  43090.0  43340.0  358200.0

# %%
dataset_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1226 entries, 2016-12-30 to 2012-04-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1226 non-null   float64
#  1   High    1226 non-null   float64
#  2   Low     1226 non-null   float64
#  3   Close   1226 non-null   float64
#  4   Volume  1226 non-null   float64
# dtypes: float64(5)
# memory usage: 57.5 KB

# %%
#dataset_test['Volume']=dataset_test['Volume'].str.replace(',','').astype(float)

# %%
test_set=dataset_test['Open']
test_set=pd.DataFrame(test_set)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1226 entries, 2016-12-30 to 2012-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1226 non-null   float64
# dtypes: float64(1)
# memory usage: 19.2 KB

# %%
# Getting the predicted stock price
import pandas as pd
dataset_total=pd.concat((dataset['Open'],dataset_test['Open']),axis=0)
inputs=dataset_total[len(dataset_total)-len(dataset_test)-66:].values
inputs=inputs.reshape(-1,1)
inputs=sc.transform(inputs)
X_test=[]
for i in range(60,80):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)
X_text=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_stock_price=regressor.predict(X_test)
predicted_stock_price=sc.inverse_transform(predicted_stock_price)
# Out:
# C:\Users\INCHARA SM\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
predicted_stock_price=pd.DataFrame(predicted_stock_price)
predicted_stock_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float32
# dtypes: float32(1)
# memory usage: 208.0 bytes

# %%
#Visualising the results
plt.plot(real_stock_price,color='red',label="Stock Price")
plt.plot(predicted_stock_price,color="blue",label="Predicted Stock Price")
plt.title("Stock price prediction")
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.legend()
plt.show()
